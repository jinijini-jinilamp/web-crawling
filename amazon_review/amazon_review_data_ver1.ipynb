# %% [markdown]
# # Amazon 상품 Review 데이터 가져오기
# * Selenium과 BeautifulSoup을 이용

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import os, warnings 
import re
warnings.filterwarnings(action='ignore') #warning message 무시하고 숨기기

# %% [markdown]
# ### 특정 상품 url로 찾아가기

# %%
driver = webdriver.Chrome('chromedriver')
url='https://www.amazon.com/dp/B07QFB9SV2/ref=sspa_dk_detail_5?psc=1&pd_rd_i=B07QFB9SV2&pd_rd_w=LvcTb&pf_rd_p=5d846283-ed3e-4512-a744-a30f97c5d738&pd_rd_wg=VLjs8&pf_rd_r=MBVK8GCEJ6A68WKE26VC&pd_rd_r=b0b15273-a074-46aa-aaa7-3c0577ab1b76&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUExQ0NISzRWWk1aTVpPJmVuY3J5cHRlZElkPUEwNzI1OTM0MlJRSEFNMUtOSDJVWCZlbmNyeXB0ZWRBZElkPUEwNTYwNjQ5M0tBUUgwWThTOVhWVSZ3aWRnZXROYW1lPXNwX2RldGFpbF90aGVtYXRpYyZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU='
driver.get(url)

# %% [markdown]
# ### 리뷰 클릭하고 전체 리뷰 보기

# %%
reviewSee = driver.find_element_by_xpath('//*[@id="acrCustomerReviewText"]')
reviewSee.click()

reviewAll = driver.find_element_by_xpath('//*[@id="cr-pagination-footer-0"]/a')
reviewAll.click()

# %% [markdown]
# ### review 정보 가지고 오기
# * review 내용 , 작성자, 평점, 작성날짜, 작성지역, 유용함 정도
# * 10개 페이지 내용 가지고 오기

# %%
review_content=[]
reviewer =[]
review_rating=[]
review_date=[]
review_area=[]
review_helpful=[]

for ck in range(10):
    page = driver.page_source
    soup = BeautifulSoup(page,'lxml')
    
    all_review_contents = soup.select('span[data-hook=review-body]')
    all_reviewer = soup.select('div[id=cm_cr-review_list] span[class=a-profile-name]')
    all_rate = soup.select('i[data-hook=review-star-rating]')
    all_date = soup.select('span[data-hook=review-date]')
    all_review_helpful=soup.find_all("div", class_="a-section review aok-relative")
    
    for j in all_review_contents:
        review_content.append(j.text.strip())

    for k in all_reviewer:
        try:
            reviewer.append(k.text.strip())
        except:
            reviewer.append('0')
    for l in all_rate:
        try:
            review_rating.append(l.text.strip()[0:3])
        except:
            review_area.append('0')
        
        #공백으로 split해서 가지고 올 수도 있다.
        #정규 표현식을 사용 할 수도 있다.
        #print(re.findall("\d+",l.text)[0])#여기서 숫자인 부분만 뽑겠다.

    for m in all_date:
        try:
            review_date.append(" ".join(m.text.split()[6:]))
        except:
            review_area.append('0')
            
        try:    
            #on이라는 문자로 나눠주기
            #print(m.text.split("on")[-1].strip())
            review_area.append(" ".join(m.text.split()[3:5]))
        except:
            review_are.append('0')
            
    for o in all_review_helpful:
        try:
            help_count=o.find("span", class_="a-size-base a-color-tertiary cr-vote-text").text.split()[0]
            if help_count == 'One':
                review_helpful.append(1)
            else    :        
                review_helpful.append(help_count)
        except:
            review_helpful.append(0)

    nextPage=driver.find_element_by_xpath('//*[@id="cm_cr-pagination_bar"]/ul/li[2]/a')
    nextPage.click()

# %% [markdown]
# ### 데이터 프레임 만들어 csv파일 생성

# %%
data ={'review': review_content, 
       'reviewer':reviewer, 
       'rate':review_rating ,
       'review_date': review_date,
       'area':review_area,
       'helpful_count':review_helpful}

data = pd.DataFrame(data)
display(data)
data.to_csv('shoppingmall_review.csv',index=False, encoding='utf-8-sig')
# Out:
#                                                review            reviewer  \
# 0   I got this for my nephew who just turned 2yo. ...             LeeAnne
# 1   Much smaller than expected. It’s very cheaply ...                lisa
# 2   Be very careful if kids pick this up the wrong...       The Curl Girl
# 3   My 3 year old likes it which is what matters t...              JESSIE
# 4   Little guy loves trucks and this is probably h...                Adam
# 5   My 3 year old grandson loves this truck. Lots ...     Sheree Hagadone
# 6   My grandson played for hours with an old CAT d...         Carol Clark
# 7   Bought for Christmas presents! The kids will l...          Amazongirl
# 8   My 3 year old nephew plays hard with his toys ...               Babzy
# 9   This is a great item. Very durable and my kid ...                Matt
# 10  I got this for my nephew who just turned 2yo. ...             LeeAnne
# 11  Much smaller than expected. It’s very cheaply ...                lisa
# 12  Be very careful if kids pick this up the wrong...       The Curl Girl
# 13  My 3 year old likes it which is what matters t...              JESSIE
# 14  Little guy loves trucks and this is probably h...                Adam
# 15  My 3 year old grandson loves this truck. Lots ...     Sheree Hagadone
# 16  My grandson played for hours with an old CAT d...         Carol Clark
# 17  Bought for Christmas presents! The kids will l...          Amazongirl
# 18  My 3 year old nephew plays hard with his toys ...               Babzy
# 19  This is a great item. Very durable and my kid ...                Matt
# 20  My one year old loves this toy. The only annoy...      Mahleea Satomi
# 21  I purchased this toy excavator for my 4 year o...   Diane Lee Wiscott
# 22  My two year old asked for a “monster dump truc...              Eileen
# 23  I purchased this for my grandson but my three ...       Mary Jacobsen
# 24  My son loves this dump truck. He plays with it...              Dhpham
# 25  Well made, takes rough play from my 1 year old...             Lologuy
# 26  Great toy for my construction-loving little on...      little_pumpkin
# 27  Bought this for my 2 year grandson and it ende...            agwalker
# 28  The sound of the truck broke after my son used...         Kim Gembara
# 29  Super cute. My three year old loves it. Unfort...                  KB
# 30  seller said truck with Lights & Sounds did not...         Stephen Arp
# 31  One button doesn’t work, we’ve only had it a f...               diana
# 32  My 2 year old loves it. I didn’t notice the bu...  Kiersten Greenaway
# 33  Bought for my son for Christmas and everything...           Alaina S.
# 34  My son played with this for a few months. It l...     Amazon Customer
# 35  My son who is 3 is obsessed with this toy. He ...           delaney86
# 36  I git this as a gift for my 1 year old grandso...        Painted_life
# 37  It's ok, but nothing I would repurchase or rec...       Iana Bakalova
